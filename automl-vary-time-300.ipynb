# %%
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score as f1

import autosklearn.classification
import warnings
warnings.simplefilter('ignore')
# Out:
# /home/peiwang/anaconda3/lib/python3.7/site-packages/pyparsing.py:3168: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile(self.reString)

# %%
# run on extracted features

for i in range(1, 9):
    for t in [300]:
        train_path = './02-feature-extract-ori/features/ft_' + str(i) + '_train.csv'
        test_path = './02-feature-extract-ori/features/ft_' + str(i) + '_test.csv'
        
        df_train = pd.read_csv(train_path)
        df_test = pd.read_csv(test_path)
        
        X_train = np.array(df_train.drop(['label'], axis=1).values.tolist())
        y_train = np.array(df_train['label'].values.tolist())
        X_test = np.array(df_test.drop(['label'], axis=1).values.tolist())
        y_test = np.array(df_test['label'].values.tolist())
        print("data_" + str(i), "training data size:", len(y_train), "test data size:", len(y_test))
        
        automl = autosklearn.classification.AutoSklearnClassifier(
                    time_left_for_this_task=t, 
                    initial_configurations_via_metalearning=0, 
                    ensemble_nbest=1, 
                    ensemble_size=1, 
                    resampling_strategy='holdout',
                    resampling_strategy_arguments={'train_size':0.75}
                )
        automl.fit(X_train, y_train, metric=autosklearn.metrics.f1)
        print("all-equipped, training fscore:", automl.score(X_train, y_train), 
              ", test fscore: ", automl.score(X_test, y_test))
        print(automl.show_models())
        print(automl.sprint_statistics())
        
        automl = autosklearn.classification.AutoSklearnClassifier(
            include_estimators=['random_forest'], 
            time_left_for_this_task=t, 
            initial_configurations_via_metalearning=0, 
            ensemble_nbest=1, ensemble_size=1, 
            resampling_strategy='holdout',
            resampling_strategy_arguments={'train_size':0.75}
        )
        automl.fit(X_train, y_train, metric=autosklearn.metrics.f1)
        print("random-forest-selected, training fscore:", automl.score(X_train, y_train),  ", test fscore: ", automl.score(X_test, y_test))
        print(automl.show_models())
        print(automl.sprint_statistics())
        print('\n')
# Out:
# data_1 training data size: 359 test data size: 91
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.613548)
# [WARNING] [2020-10-06 21:40:52,062:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 21:40:52,072:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.9557522123893806 , test fscore:  0.7878787878787878
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'none', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.25464968846947544, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 16, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_rates:alpha': 0.41336416745154897, 'preprocessor:select_rates:mode': 'fdr', 'preprocessor:select_rates:score_func': 'f_classif'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: f5b46c9d028f95632fa5cdb335a7227e
#   Metric: f1
#   Best validation score: 0.965517
#   Number of target algorithm runs: 135
#   Number of successful target algorithm runs: 135
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0
#
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.736604)
# [WARNING] [2020-10-06 21:45:47,375:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 21:45:47,384:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.9541284403669724 , test fscore:  0.8235294117647058
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'minmax', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.8318400943261534, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 5, 'classifier:random_forest:min_samples_split': 6, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_rates:alpha': 0.24241909389015023, 'preprocessor:select_rates:mode': 'fpr', 'preprocessor:select_rates:score_func': 'f_classif', 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.004453142811851807},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: f5b46c9d028f95632fa5cdb335a7227e
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 173
#   Number of successful target algorithm runs: 171
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
# data_2 training data size: 757 test data size: 189
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.595567)
# [WARNING] [2020-10-06 21:50:42,045:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 21:50:42,054:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# all-equipped, training fscore: 1.0 , test fscore:  1.0
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'gradient_boosting', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'quantile_transformer', 'classifier:gradient_boosting:early_stop': 'valid', 'classifier:gradient_boosting:l2_regularization': 0.042659026159600016, 'classifier:gradient_boosting:learning_rate': 0.7532522896808316, 'classifier:gradient_boosting:loss': 'auto', 'classifier:gradient_boosting:max_bins': 256, 'classifier:gradient_boosting:max_depth': 'None', 'classifier:gradient_boosting:max_iter': 76, 'classifier:gradient_boosting:max_leaf_nodes': 786, 'classifier:gradient_boosting:min_samples_leaf': 43, 'classifier:gradient_boosting:scoring': 'loss', 'classifier:gradient_boosting:tol': 1e-07, 'preprocessor:select_rates:alpha': 0.19830638718406884, 'preprocessor:select_rates:mode': 'fpr', 'preprocessor:select_rates:score_func': 'chi2', 'rescaling:quantile_transformer:n_quantiles': 1448, 'rescaling:quantile_transformer:output_distribution': 'normal', 'classifier:gradient_boosting:n_iter_no_change': 9, 'classifier:gradient_boosting:validation_fraction': 0.194818084481959},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: bd66db206a7b1a4510d937039c72d454
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 66
#   Number of successful target algorithm runs: 63
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 2
#
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.742754)
# [WARNING] [2020-10-06 21:55:36,631:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 21:55:36,646:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 1.0 , test fscore:  1.0
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'random_trees_embedding', 'rescaling:__choice__': 'normalize', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5849217538799182, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 15, 'classifier:random_forest:min_samples_split': 6, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:random_trees_embedding:bootstrap': 'True', 'preprocessor:random_trees_embedding:max_depth': 3, 'preprocessor:random_trees_embedding:max_leaf_nodes': 'None', 'preprocessor:random_trees_embedding:min_samples_leaf': 11, 'preprocessor:random_trees_embedding:min_samples_split': 13, 'preprocessor:random_trees_embedding:min_weight_fraction_leaf': 1.0, 'preprocessor:random_trees_embedding:n_estimators': 49},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: bd66db206a7b1a4510d937039c72d454
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 127
#   Number of successful target algorithm runs: 126
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
# data_3 training data size: 430 test data size: 109
# [WARNING] [2020-10-06 22:00:31,345:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.496547)
# [WARNING] [2020-10-06 22:00:31,356:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# all-equipped, training fscore: 1.0 , test fscore:  0.9310344827586207
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'liblinear_svc', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'liblinear_svc_preprocessor', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:liblinear_svc:C': 1.0, 'classifier:liblinear_svc:dual': 'False', 'classifier:liblinear_svc:fit_intercept': 'True', 'classifier:liblinear_svc:intercept_scaling': 1, 'classifier:liblinear_svc:loss': 'squared_hinge', 'classifier:liblinear_svc:multi_class': 'ovr', 'classifier:liblinear_svc:penalty': 'l2', 'classifier:liblinear_svc:tol': 0.00010000000000000009, 'preprocessor:liblinear_svc_preprocessor:C': 1.0, 'preprocessor:liblinear_svc_preprocessor:dual': 'False', 'preprocessor:liblinear_svc_preprocessor:fit_intercept': 'True', 'preprocessor:liblinear_svc_preprocessor:intercept_scaling': 1, 'preprocessor:liblinear_svc_preprocessor:loss': 'squared_hinge', 'preprocessor:liblinear_svc_preprocessor:multi_class': 'ovr', 'preprocessor:liblinear_svc_preprocessor:penalty': 'l1', 'preprocessor:liblinear_svc_preprocessor:tol': 0.00010000000000000009, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.010000000000000004},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 635daed483007aa9eb9d0f13ef1e2ecb
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 57
#   Number of successful target algorithm runs: 55
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 1
#
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.744603)
# [WARNING] [2020-10-06 22:05:25,890:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:05:25,904:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.9811320754716981 , test fscore:  0.9310344827586207
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'none', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.36065827933500955, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 5, 'classifier:random_forest:min_samples_split': 18, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_rates:alpha': 0.36694965607771735, 'preprocessor:select_rates:mode': 'fdr', 'preprocessor:select_rates:score_func': 'chi2'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 635daed483007aa9eb9d0f13ef1e2ecb
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 79
#   Number of successful target algorithm runs: 77
#   Number of crashed target algorithm runs: 2
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
# data_4 training data size: 9890 test data size: 2473
# [WARNING] [2020-10-06 22:10:20,829:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:10:20,839:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.574812)
# all-equipped, training fscore: 0.9963390594198818 , test fscore:  0.984304932735426
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.01},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 96e15f368892904cfcdb2aa7c67c362e
#   Metric: f1
#   Best validation score: 0.985344
#   Number of target algorithm runs: 8
#   Number of successful target algorithm runs: 6
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 1
#
# [WARNING] [2020-10-06 22:15:15,433:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:15:15,442:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.696285)
# random-forest-selected, training fscore: 0.9891213389121339 , test fscore:  0.978912319644839
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'feature_agglomeration', 'rescaling:__choice__': 'robust_scaler', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5790763138416702, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 3, 'classifier:random_forest:min_samples_split': 20, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:feature_agglomeration:affinity': 'euclidean', 'preprocessor:feature_agglomeration:linkage': 'complete', 'preprocessor:feature_agglomeration:n_clusters': 87, 'preprocessor:feature_agglomeration:pooling_func': 'mean', 'rescaling:robust_scaler:q_max': 0.9388342816905029, 'rescaling:robust_scaler:q_min': 0.24221743551152783},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 96e15f368892904cfcdb2aa7c67c362e
#   Metric: f1
#   Best validation score: 0.985475
#   Number of target algorithm runs: 44
#   Number of successful target algorithm runs: 39
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 4
# data_5 training data size: 22965 test data size: 5742
# [WARNING] [2020-10-06 22:20:11,227:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:20:11,237:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.477313)
# [WARNING] [2020-10-06 22:20:13,242:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:20:15,249:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.9864136800187396 , test fscore:  0.9418874941887495
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.01},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 007e1b70e0021aaf0b98693d46275332
#   Metric: f1
#   Best validation score: 0.945335
#   Number of target algorithm runs: 9
#   Number of successful target algorithm runs: 6
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 2
#
# [WARNING] [2020-10-06 22:25:06,088:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:25:06,098:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.608458)
# [WARNING] [2020-10-06 22:25:08,104:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:25:10,109:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.9864136800187396 , test fscore:  0.9418874941887495
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.01},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 007e1b70e0021aaf0b98693d46275332
#   Metric: f1
#   Best validation score: 0.945335
#   Number of target algorithm runs: 25
#   Number of successful target algorithm runs: 23
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 2
#
#
#
# data_6 training data size: 9167 test data size: 2293
# [WARNING] [2020-10-06 22:30:01,210:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:30:01,220:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.560265)
# [WARNING] [2020-10-06 22:30:03,224:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.7930402930402929 , test fscore:  0.6479400749063671
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'extra_trees', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'select_percentile_classification', 'rescaling:__choice__': 'quantile_transformer', 'classifier:extra_trees:bootstrap': 'False', 'classifier:extra_trees:criterion': 'entropy', 'classifier:extra_trees:max_depth': 'None', 'classifier:extra_trees:max_features': 0.9737141481484574, 'classifier:extra_trees:max_leaf_nodes': 'None', 'classifier:extra_trees:min_impurity_decrease': 0.0, 'classifier:extra_trees:min_samples_leaf': 4, 'classifier:extra_trees:min_samples_split': 9, 'classifier:extra_trees:min_weight_fraction_leaf': 0.0, 'classifier:extra_trees:n_estimators': 100, 'preprocessor:select_percentile_classification:percentile': 48.55322714585354, 'preprocessor:select_percentile_classification:score_func': 'f_classif', 'rescaling:quantile_transformer:n_quantiles': 1561, 'rescaling:quantile_transformer:output_distribution': 'uniform'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 4ab864c8876c543722442b506ccbf935
#   Metric: f1
#   Best validation score: 0.606947
#   Number of target algorithm runs: 9
#   Number of successful target algorithm runs: 7
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 1
#
# [WARNING] [2020-10-06 22:34:55,926:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:34:55,935:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.698271)
# random-forest-selected, training fscore: 0.7558039552880481 , test fscore:  0.6431095406360424
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'none', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.6522065045833896, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 9, 'classifier:random_forest:min_samples_split': 3, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 4ab864c8876c543722442b506ccbf935
#   Metric: f1
#   Best validation score: 0.606780
#   Number of target algorithm runs: 35
#   Number of successful target algorithm runs: 29
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 4
# data_7 training data size: 8193 test data size: 2049
# [WARNING] [2020-10-06 22:39:51,031:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:39:51,041:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.489450)
# [WARNING] [2020-10-06 22:39:53,045:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.9509738079247817 , test fscore:  0.7823529411764705
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.01},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: a619ef2c1fe74f7db94dc7cc716bf72b
#   Metric: f1
#   Best validation score: 0.782090
#   Number of target algorithm runs: 9
#   Number of successful target algorithm runs: 6
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 2
#
# [WARNING] [2020-10-06 22:44:45,848:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:44:45,858:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.690263)
# [WARNING] [2020-10-06 22:44:47,864:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:49:37,187:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-06 22:49:37,187:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# random-forest-selected, training fscore: 0.9427254772876893 , test fscore:  0.8076923076923078
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'select_percentile_classification', 'rescaling:__choice__': 'standardize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.866485764561651, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 2, 'classifier:random_forest:min_samples_split': 5, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_percentile_classification:percentile': 70.29188948082485, 'preprocessor:select_percentile_classification:score_func': 'mutual_info'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: a619ef2c1fe74f7db94dc7cc716bf72b
#   Metric: f1
#   Best validation score: 0.800000
#   Number of target algorithm runs: 35
#   Number of successful target algorithm runs: 30
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 4
#
#
#
# data_8 training data size: 7659 test data size: 1916
# [WARNING] [2020-10-06 22:49:40,792:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:49:40,801:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.581134)
# [WARNING] [2020-10-06 22:49:42,806:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.8977777777777778 , test fscore:  0.5791044776119403
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'gradient_boosting', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'extra_trees_preproc_for_classification', 'rescaling:__choice__': 'robust_scaler', 'classifier:gradient_boosting:early_stop': 'off', 'classifier:gradient_boosting:l2_regularization': 4.600806153652073e-07, 'classifier:gradient_boosting:learning_rate': 0.06275432016233436, 'classifier:gradient_boosting:loss': 'auto', 'classifier:gradient_boosting:max_bins': 256, 'classifier:gradient_boosting:max_depth': 'None', 'classifier:gradient_boosting:max_iter': 349, 'classifier:gradient_boosting:max_leaf_nodes': 77, 'classifier:gradient_boosting:min_samples_leaf': 84, 'classifier:gradient_boosting:scoring': 'loss', 'classifier:gradient_boosting:tol': 1e-07, 'preprocessor:extra_trees_preproc_for_classification:bootstrap': 'True', 'preprocessor:extra_trees_preproc_for_classification:criterion': 'gini', 'preprocessor:extra_trees_preproc_for_classification:max_depth': 'None', 'preprocessor:extra_trees_preproc_for_classification:max_features': 0.7161115036007507, 'preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': 'None', 'preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': 0.0, 'preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': 7, 'preprocessor:extra_trees_preproc_for_classification:min_samples_split': 6, 'preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': 0.0, 'preprocessor:extra_trees_preproc_for_classification:n_estimators': 100, 'rescaling:robust_scaler:q_max': 0.9595095582730568, 'rescaling:robust_scaler:q_min': 0.031173934230901465},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: fcf3cd40185117d08e556947af92a53e
#   Metric: f1
#   Best validation score: 0.568966
#   Number of target algorithm runs: 21
#   Number of successful target algorithm runs: 18
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 2
#
# [WARNING] [2020-10-06 22:54:35,953:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:54:35,962:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# Time limit for a single run is higher than total time limit. Capping the limit for a single run to the total time given to SMAC (299.712302)
# [WARNING] [2020-10-06 22:54:37,965:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.7107843137254902 , test fscore:  0.539877300613497
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'feature_agglomeration', 'rescaling:__choice__': 'none', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.8157549179858324, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 16, 'classifier:random_forest:min_samples_split': 11, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:feature_agglomeration:affinity': 'manhattan', 'preprocessor:feature_agglomeration:linkage': 'complete', 'preprocessor:feature_agglomeration:n_clusters': 219, 'preprocessor:feature_agglomeration:pooling_func': 'max', 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.00019621885521160264},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: fcf3cd40185117d08e556947af92a53e
#   Metric: f1
#   Best validation score: 0.589178
#   Number of target algorithm runs: 36
#   Number of successful target algorithm runs: 32
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 3
