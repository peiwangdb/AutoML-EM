# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("./magellan-vector/test_s1.csv")

# %%
df
# Out:
#        _id  ltable_id  rtable_id  id_id_exm  id_id_anm  id_id_lev_dist  \
# 0        0       1496       1225        0.0   0.818850             3.0
# 1        1        574        749        0.0   0.766355             2.0
# 2        2        561       1957        0.0   0.286663             4.0
# 3        3       1799       1307        0.0   0.726515             3.0
# 4        4       1116       1205        0.0   0.926141             3.0
# ...    ...        ...        ...        ...        ...             ...
# 2468  2468       2202       1324        0.0   0.601272             4.0
# 2469  2469         94       2277        0.0   0.041282             4.0
# 2470  2470          5       1921        0.0   0.002603             4.0
# 2471  2471       2451        539        0.0   0.219910             4.0
# 2472  2472       1577        518        0.0   0.328472             3.0
#
#       id_id_lev_sim  title_title_jac_qgm_3_qgm_3  \
# 0          0.250000                     0.346154
# ...

# %%
df = pd.read_csv("./processed_vectors_structured/data_1_test.csv")

# %%
df
# Out:
#       Unnamed: 0  true___str___affine___ltable_id___rtable_id  \
# 0              0                                          0.0
# 1              1                                          0.0
# 2              2                                         -1.0
# 3              3                                          0.0
# 4              4                                          1.0
# ...          ...                                          ...
# 2288        2288                                         -1.0
# 2289        2289                                          0.0
# 2290        2290                                          0.0
# 2291        2291                                          0.0
# 2292        2292                                          0.0
#
#       true___str___lev_dist___ltable_id___rtable_id  \
# 0                                                 3
# 1                                                 3
# 2                                                 4
# ...
