# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../magellan-vector/test_s2.csv")
print(len(df))
# Out:
# 91

# %%
i = 1
for i in range(1, 9):
    train_path = '../features/ft_' + str(i) + '_train.csv'
    df = pd.read_csv(train_path)
    print(len(df.columns.to_list())-2)
# Out:
# 87
# 123
# 155
# 89
# 89
# 72
# 106
# 72

# %%
df
# Out:
#     _id  ltable_id  rtable_id  id_id_exm  id_id_anm  id_id_lev_dist  \
# 0     0       1219       2470        0.0   0.493522             4.0
# 1     1        492       1635        0.0   0.300917             4.0
# 2     2       3917       2224        0.0   0.567781             4.0
# 3     3       2155       2948        0.0   0.731004             3.0
# 4     4        271       1410        0.0   0.192199             3.0
# ..  ...        ...        ...        ...        ...             ...
# 86   86       2115         77        0.0   0.036407             4.0
# 87   87       4063       2331        0.0   0.573714             4.0
# 88   88       4161       2409        0.0   0.578947             4.0
# 89   89        862       2906        0.0   0.296628             4.0
# 90   90       2242       1048        0.0   0.467440             3.0
#
#     id_id_lev_sim  Beer_Name_Beer_Name_jac_qgm_3_qgm_3  \
# 0            0.00                             0.360656
# ...

# %%
2293 - 21
91 - 87
2473 - 18
5742 - 18
189 - 37
2049 - 32
109 - 30
1916 - 15
