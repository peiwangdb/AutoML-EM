# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
methods = ['DeepMatcher', 'AutoML-EM']
deep_list = [72.7, 100, 88.0, 98.4, 94.7, 69.3, 66.9, 62.8]
our_list = [80.9, 100, 95.7, 98.1, 94.6, 63.8, 79.9, 58.1]
labels = ['BeerAdvo-RateBeer', 'Fodors-Zagats', 'iTunes-Amazon', 'DBLP-ACM', 'DBLP-Scholar', 'Amazon-Google', 'Walmart-Amazon', 'Abt-Buy']

# %%
83.89 - 78.16
# Out:
# 5.730000000000004

# %%
m_list = [78.8, 100, 91.2, 98.4, 92.3, 49.1, 71.9, 43.6]
sum(m_list)/8
# Out:
# 78.16250000000001

# %%
x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.barh(x - width/2 - 0.05, deep_list, width, label='DeepMatcher')
rects2 = ax.barh(x + width/2, our_list, width, label='AutoML-EM')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('F1 Score on Test Data (%)', fontsize=20)
# ax.set_title('Comparison of AutoML-EM and DeepMatcher')
# ax.set_yticks([40, 60, 80, 100])
ax.set_yticks(x)
ax.set_yticklabels(labels)
ax.legend()
plt.tick_params(labelsize=20)


# for i, v in enumerate(y):
#     ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')

# def autolabel(rects):
#     """Attach a text label above each bar in *rects*, displaying its height."""
#     for rect in rects:
#         height = rect.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(rect.get_x() + rect.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom', rotation=20)

def autolabel(rects):
    for rect in rects:
        # Get X and Y placement of label from rect.
        x_value = rect.get_width()
        y_value = rect.get_y() + rect.get_height() / 2

        # Number of points between bar and label. Change to your liking.
        space = 5
        # Vertical alignment for positive values
        ha = 'left'

        # If value of bar is negative: Place label left of bar
        if x_value < 0:
            # Invert space to place label to the left
            space *= -1
            # Horizontally align label at right
            ha = 'right'

        # Use X value as label and format number with one decimal place
        label = "{:.1f}".format(x_value)

        # Create annotation
        plt.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(space, 0),          # Horizontally shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            va='center',                # Vertically center label
            ha=ha,
            fontsize=15)                      # Horizontally align label differently for
                                    # positive and negative values.


autolabel(rects1)
autolabel(rects2)

plt.xlim([0, 115])
plt.legend(loc=0, prop={'size': 13})
fig.set_size_inches(9, 6)
fig.tight_layout()

plt.savefig('deepmatcher.pdf')
plt.show()
