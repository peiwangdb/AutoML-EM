# %%
import pandas as pd
import numpy as np

from sklearn.metrics import f1_score as f1

import autosklearn.classification
import warnings
warnings.simplefilter('ignore')

pd.set_option('display.max_columns', None)
# Out:
# /home/peiwang/anaconda3/lib/python3.7/site-packages/pyparsing.py:3168: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile(self.reString)

# %%
# load magellan featrues

m_train = []
m_test = []

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s2.csv") # 91
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s2.csv") # 91
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s5.csv") # 189
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s5.csv") # 189
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s7.csv") # 109
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s7.csv") # 109
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s3.csv") # 2473
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s3.csv") # 2473
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s4.csv") # 5742
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s4.csv") # 5742
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s1.csv") # 2293
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s1.csv") # 2293
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_s6.csv") # 2049
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_s6.csv") # 2049
m_train.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/test_t1.csv") # 1916
m_test.append(df)

df = pd.read_csv("./02-feature-extract-ori/magellan-vector/train_t1.csv") # 1916
m_train.append(df)

# %%
for i in range(0, 8):
    print(len(m_train[i]), len(m_test[i]), len(m_train[i].columns.to_list()) - 4)
# Out:
# 359 91 36
# 757 189 37
# 430 109 30
# 9890 2473 18
# 22965 5742 18
# 9167 2293 21
# 8193 2049 32
# 7659 1916 15

# %%
f_train = []
f_test = []

for i in range(1, 9):
    df_train = pd.read_csv("./02-feature-extract-ori/features/ft_" + str(i) + "_train.csv") 
    df_test = pd.read_csv("./02-feature-extract-ori/features/ft_" + str(i) + "_test.csv") 
    f_train.append(df_train)
    f_test.append(df_test)
    print(len(df_train), len(df_test), len(df_train.columns.to_list()) - 2)
# Out:
# 359 91 87
# 757 189 123
# 430 109 155
# 9890 2473 89
# 22965 5742 89
# 9167 2293 72
# 8193 2049 106
# 7659 1916 72

# %%
# compare the test score

for i in range(0, 8):
    print('round:', i)
    
#     df_train_m = m_train[i]
#     df_test_m = m_test[i]
    
#     print(len(df_train_m), len(df_test_m), len(df_train_m.columns.to_list()) - 2)
    
#     X_train_m = np.array(df_train_m.drop(['label'], axis=1).values.tolist())
#     y_train_m = np.array(df_train_m['label'].values.tolist())
#     X_test_m = np.array(df_test_m.drop(['label'], axis=1).values.tolist())
#     y_test_m = np.array(df_test_m['label'].values.tolist())
    
#     automl = autosklearn.classification.AutoSklearnClassifier(
#             include_estimators=['random_forest'], 
#             time_left_for_this_task=3600, 
#             initial_configurations_via_metalearning=0, 
#             seed = 1,
#             ensemble_nbest=1, 
#             ensemble_size=1, 
#             resampling_strategy='holdout',
#             resampling_strategy_arguments={'train_size':0.75, 'random_state':42}
#         )
#     automl.fit(X_train_m, y_train_m, metric=autosklearn.metrics.f1)
#     print("Magellan: training fscore:", automl.score(X_train_m, y_train_m),  
#               ", test fscore: ", automl.score(X_test_m, y_test_m), '\n')
#     print(automl.show_models())
#     print(automl.sprint_statistics())
    
    df_train_f = f_train[i]
    df_test_f = f_test[i]
    
    print(len(df_train_f), len(df_test_f), len(df_train_f.columns.to_list()) - 2)
    
    X_train_f = np.array(df_train_f.drop(['label'], axis=1).values.tolist())
    y_train_f = np.array(df_train_f['label'].values.tolist())
    X_test_f = np.array(df_test_f.drop(['label'], axis=1).values.tolist())
    y_test_f = np.array(df_test_f['label'].values.tolist())
    
    automl = autosklearn.classification.AutoSklearnClassifier(
            include_estimators=['random_forest'], 
            time_left_for_this_task=3600, 
            initial_configurations_via_metalearning=0, 
            seed = 1,
            ensemble_nbest=1, 
            ensemble_size=1, 
            resampling_strategy='holdout',
            resampling_strategy_arguments={'train_size':0.75, 'random_state':42}
        )
    automl.fit(X_train_f, y_train_f, metric=autosklearn.metrics.f1)
    print("AutoML-EM: training fscore:", automl.score(X_train_f, y_train_f),  
              ", test fscore: ", automl.score(X_test_f, y_test_f), '\n')
    print(automl.show_models())
    print(automl.sprint_statistics())
    
    
    print('\n\n\n')
# Out:
# round: 0
# 359 91 87
# [WARNING] [2020-10-12 19:21:04,825:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 19:21:04,835:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 19:22:51,097:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-12 19:22:51,097:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# AutoML-EM: training fscore: 0.9636363636363636 , test fscore:  0.8235294117647058
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'none', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5772857886008773, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 5, 'classifier:random_forest:min_samples_split': 14, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_rates:alpha': 0.0988301080733714, 'preprocessor:select_rates:mode': 'fpr', 'preprocessor:select_rates:score_func': 'f_classif'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: f5b46c9d028f95632fa5cdb335a7227e
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 773
#   Number of successful target algorithm runs: 758
#   Number of crashed target algorithm runs: 14
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
#
#
# round: 1
# 757 189 123
# [WARNING] [2020-10-12 20:21:00,159:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 20:21:00,169:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# AutoML-EM: training fscore: 0.9942857142857142 , test fscore:  1.0
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'random_trees_embedding', 'rescaling:__choice__': 'minmax', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.22365901592567947, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 13, 'classifier:random_forest:min_samples_split': 14, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:random_trees_embedding:bootstrap': 'True', 'preprocessor:random_trees_embedding:max_depth': 6, 'preprocessor:random_trees_embedding:max_leaf_nodes': 'None', 'preprocessor:random_trees_embedding:min_samples_leaf': 17, 'preprocessor:random_trees_embedding:min_samples_split': 14, 'preprocessor:random_trees_embedding:min_weight_fraction_leaf': 1.0, 'preprocessor:random_trees_embedding:n_estimators': 46},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: bd66db206a7b1a4510d937039c72d454
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 1223
#   Number of successful target algorithm runs: 1210
#   Number of crashed target algorithm runs: 13
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
#
#
# round: 2
# 430 109 155
# [WARNING] [2020-10-12 21:20:55,976:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 21:20:55,985:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# AutoML-EM: training fscore: 1.0 , test fscore:  0.9629629629629629
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'polynomial', 'rescaling:__choice__': 'quantile_transformer', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.9956776120629645, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 3, 'classifier:random_forest:min_samples_split': 5, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:polynomial:degree': 2, 'preprocessor:polynomial:include_bias': 'True', 'preprocessor:polynomial:interaction_only': 'True', 'rescaling:quantile_transformer:n_quantiles': 1371, 'rescaling:quantile_transformer:output_distribution': 'uniform'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 635daed483007aa9eb9d0f13ef1e2ecb
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 289
#   Number of successful target algorithm runs: 285
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
#
#
# round: 3
# 9890 2473 89
# [WARNING] [2020-10-12 22:20:50,989:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 22:20:51,001:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# AutoML-EM: training fscore: 0.9842873176206509 , test fscore:  0.9786276715410572
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'fast_ica', 'rescaling:__choice__': 'standardize', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.120085897305521, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 12, 'classifier:random_forest:min_samples_split': 15, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:fast_ica:algorithm': 'parallel', 'preprocessor:fast_ica:fun': 'logcosh', 'preprocessor:fast_ica:whiten': 'False'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 96e15f368892904cfcdb2aa7c67c362e
#   Metric: f1
#   Best validation score: 0.987654
#   Number of target algorithm runs: 113
#   Number of successful target algorithm runs: 104
#   Number of crashed target algorithm runs: 4
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 4
#
#
#
#
#
# round: 4
# 22965 5742 89
# [WARNING] [2020-10-12 23:20:46,121:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 23:20:46,133:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 23:20:48,138:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-12 23:20:50,143:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# AutoML-EM: training fscore: 0.9820612029546254 , test fscore:  0.9455053563111318
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'polynomial', 'rescaling:__choice__': 'standardize', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.6031796281835515, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 10, 'classifier:random_forest:min_samples_split': 9, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:polynomial:degree': 2, 'preprocessor:polynomial:include_bias': 'True', 'preprocessor:polynomial:interaction_only': 'True'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 007e1b70e0021aaf0b98693d46275332
#   Metric: f1
#   Best validation score: 0.950542
#   Number of target algorithm runs: 78
#   Number of successful target algorithm runs: 67
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 3
#   Number of target algorithms that exceeded the memory limit: 8
#
#
#
#
#
# round: 5
# 9167 2293 72
# [WARNING] [2020-10-13 00:20:44,939:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-13 00:20:44,949:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-13 01:01:57,263:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-13 01:01:57,263:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# AutoML-EM: training fscore: 0.7902129587675577 , test fscore:  0.6641509433962264
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'select_percentile_classification', 'rescaling:__choice__': 'quantile_transformer', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.445671410329053, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 4, 'classifier:random_forest:min_samples_split': 19, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_percentile_classification:percentile': 81.60167271958024, 'preprocessor:select_percentile_classification:score_func': 'f_classif', 'rescaling:quantile_transformer:n_quantiles': 708, 'rescaling:quantile_transformer:output_distribution': 'uniform'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 4ab864c8876c543722442b506ccbf935
#   Metric: f1
#   Best validation score: 0.622061
#   Number of target algorithm runs: 250
#   Number of successful target algorithm runs: 235
#   Number of crashed target algorithm runs: 6
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 8
#
#
#
#
#
# round: 6
# 8193 2049 106
# [WARNING] [2020-10-13 01:20:40,479:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-13 01:20:40,489:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-13 01:20:42,494:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# AutoML-EM: training fscore: 0.8947040498442369 , test fscore:  0.785
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'liblinear_svc_preprocessor', 'rescaling:__choice__': 'minmax', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.7285252940070654, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 6, 'classifier:random_forest:min_samples_split': 6, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:liblinear_svc_preprocessor:C': 0.2706948101698689, 'preprocessor:liblinear_svc_preprocessor:dual': 'False', 'preprocessor:liblinear_svc_preprocessor:fit_intercept': 'True', 'preprocessor:liblinear_svc_preprocessor:intercept_scaling': 1, 'preprocessor:liblinear_svc_preprocessor:loss': 'squared_hinge', 'preprocessor:liblinear_svc_preprocessor:multi_class': 'ovr', 'preprocessor:liblinear_svc_preprocessor:penalty': 'l1', 'preprocessor:liblinear_svc_preprocessor:tol': 1.8870833095107427e-05},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: a619ef2c1fe74f7db94dc7cc716bf72b
#   Metric: f1
#   Best validation score: 0.806452
#   Number of target algorithm runs: 150
#   Number of successful target algorithm runs: 138
#   Number of crashed target algorithm runs: 5
#   Number of target algorithms that exceeded the time limit: 3
#   Number of target algorithms that exceeded the memory limit: 4
#
#
#
#
#
# round: 7
# 7659 1916 72
# [WARNING] [2020-10-13 02:20:35,251:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-13 02:20:35,262:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-13 02:20:37,273:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# AutoML-EM: training fscore: 0.8602520045819015 , test fscore:  0.5924170616113744
#
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'extra_trees_preproc_for_classification', 'rescaling:__choice__': 'minmax', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.8963256307686189, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 5, 'classifier:random_forest:min_samples_split': 4, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:extra_trees_preproc_for_classification:bootstrap': 'False', 'preprocessor:extra_trees_preproc_for_classification:criterion': 'gini', 'preprocessor:extra_trees_preproc_for_classification:max_depth': 'None', 'preprocessor:extra_trees_preproc_for_classification:max_features': 0.5, 'preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': 'None', 'preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': 0.0, 'preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': 1, 'preprocessor:extra_trees_preproc_for_classification:min_samples_split': 2, 'preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': 0.0, 'preprocessor:extra_trees_preproc_for_classification:n_estimators': 100},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: fcf3cd40185117d08e556947af92a53e
#   Metric: f1
#   Best validation score: 0.632319
#   Number of target algorithm runs: 194
#   Number of successful target algorithm runs: 176
#   Number of crashed target algorithm runs: 2
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 12
