# %%
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score as f1

import autosklearn.classification
import warnings
warnings.simplefilter('ignore')
# Out:
# /home/peiwang/anaconda3/lib/python3.7/site-packages/pyparsing.py:3168: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile(self.reString)

# %%
# run on extracted features

for i in range(1, 9):
    for t in [3600]:
        train_path = './02-feature-extract-ori/features/ft_' + str(i) + '_train.csv'
        test_path = './02-feature-extract-ori/features/ft_' + str(i) + '_test.csv'
        
        df_train = pd.read_csv(train_path)
        df_test = pd.read_csv(test_path)
        
        X_train = np.array(df_train.drop(['label'], axis=1).values.tolist())
        y_train = np.array(df_train['label'].values.tolist())
        X_test = np.array(df_test.drop(['label'], axis=1).values.tolist())
        y_test = np.array(df_test['label'].values.tolist())
        print("data_" + str(i), "training data size:", len(y_train), "test data size:", len(y_test))
        
        automl = autosklearn.classification.AutoSklearnClassifier(
            time_left_for_this_task=t, 
            initial_configurations_via_metalearning=0, 
            ensemble_nbest=1, 
            ensemble_size=1, 
            resampling_strategy='holdout',
            resampling_strategy_arguments={'train_size':0.75}
        )
        automl.fit(X_train, y_train, metric=autosklearn.metrics.f1)
        print("\n all-equipped, training fscore:", automl.score(X_train, y_train), 
              ", test fscore: ", automl.score(X_test, y_test), '\n')
        print(automl.show_models())
        print(automl.sprint_statistics())
        
        
        automl = autosklearn.classification.AutoSklearnClassifier(
            include_estimators=['random_forest'], 
            time_left_for_this_task=t, 
            initial_configurations_via_metalearning=0, 
            ensemble_nbest=1, 
            ensemble_size=1, 
            resampling_strategy='holdout',
            resampling_strategy_arguments={'train_size':0.75}
        )
        automl.fit(X_train, y_train, metric=autosklearn.metrics.f1)
        print("\n random-forest-selected, training fscore:", automl.score(X_train, y_train),  
              ", test fscore: ", automl.score(X_test, y_test), '\n')
        print(automl.show_models())
        print(automl.sprint_statistics())
        print('\n')
# Out:
# data_1 training data size: 359 test data size: 91
# [WARNING] [2020-10-06 21:40:25,548:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 21:40:25,558:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 21:41:28,292:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-06 21:41:28,292:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# all-equipped, training fscore: 0.9818181818181818 , test fscore:  0.7272727272727273
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'passive_aggressive', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'fast_ica', 'rescaling:__choice__': 'robust_scaler', 'classifier:passive_aggressive:C': 0.0024394472653309035, 'classifier:passive_aggressive:average': 'False', 'classifier:passive_aggressive:fit_intercept': 'True', 'classifier:passive_aggressive:loss': 'squared_hinge', 'classifier:passive_aggressive:tol': 0.003464674323538802, 'preprocessor:fast_ica:algorithm': 'deflation', 'preprocessor:fast_ica:fun': 'exp', 'preprocessor:fast_ica:whiten': 'True', 'rescaling:robust_scaler:q_max': 0.825653784106447, 'rescaling:robust_scaler:q_min': 0.25, 'preprocessor:fast_ica:n_components': 1144},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: f5b46c9d028f95632fa5cdb335a7227e
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 1074
#   Number of successful target algorithm runs: 1064
#   Number of crashed target algorithm runs: 4
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 6
#
# [WARNING] [2020-10-06 22:40:22,781:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 22:40:22,790:EnsembleBuilder(1):f5b46c9d028f95632fa5cdb335a7227e] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.9174311926605504 , test fscore:  0.7999999999999999
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'random_trees_embedding', 'rescaling:__choice__': 'robust_scaler', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.9574045181026932, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 12, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:random_trees_embedding:bootstrap': 'True', 'preprocessor:random_trees_embedding:max_depth': 2, 'preprocessor:random_trees_embedding:max_leaf_nodes': 'None', 'preprocessor:random_trees_embedding:min_samples_leaf': 11, 'preprocessor:random_trees_embedding:min_samples_split': 3, 'preprocessor:random_trees_embedding:min_weight_fraction_leaf': 1.0, 'preprocessor:random_trees_embedding:n_estimators': 61, 'rescaling:robust_scaler:q_max': 0.9400842218263862, 'rescaling:robust_scaler:q_min': 0.29556397335257834},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: f5b46c9d028f95632fa5cdb335a7227e
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 1671
#   Number of successful target algorithm runs: 1660
#   Number of crashed target algorithm runs: 11
#   Number of target algorithms that exceeded the time limit: 0
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
# data_2 training data size: 757 test data size: 189
# [WARNING] [2020-10-06 23:40:19,876:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# [WARNING] [2020-10-06 23:40:19,888:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# all-equipped, training fscore: 1.0 , test fscore:  1.0
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'polynomial', 'rescaling:__choice__': 'none', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.9884553874772145, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 20, 'classifier:random_forest:min_samples_split': 14, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:polynomial:degree': 2, 'preprocessor:polynomial:include_bias': 'True', 'preprocessor:polynomial:interaction_only': 'False'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: bd66db206a7b1a4510d937039c72d454
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 529
#   Number of successful target algorithm runs: 506
#   Number of crashed target algorithm runs: 10
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 9
#
# [WARNING] [2020-10-07 00:40:15,396:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 00:40:15,407:EnsembleBuilder(1):bd66db206a7b1a4510d937039c72d454] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 1.0 , test fscore:  1.0
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'normalize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.713544352039558, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 10, 'classifier:random_forest:min_samples_split': 14, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_rates:alpha': 0.41158017539763336, 'preprocessor:select_rates:mode': 'fwe', 'preprocessor:select_rates:score_func': 'f_classif', 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.237564173987166},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: bd66db206a7b1a4510d937039c72d454
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 776
#   Number of successful target algorithm runs: 764
#   Number of crashed target algorithm runs: 8
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
# data_3 training data size: 430 test data size: 109
# [WARNING] [2020-10-07 01:40:10,246:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 01:40:10,259:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# all-equipped, training fscore: 1.0 , test fscore:  0.9615384615384615
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'liblinear_svc', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'polynomial', 'rescaling:__choice__': 'quantile_transformer', 'classifier:liblinear_svc:C': 19722.52974801747, 'classifier:liblinear_svc:dual': 'False', 'classifier:liblinear_svc:fit_intercept': 'True', 'classifier:liblinear_svc:intercept_scaling': 1, 'classifier:liblinear_svc:loss': 'squared_hinge', 'classifier:liblinear_svc:multi_class': 'ovr', 'classifier:liblinear_svc:penalty': 'l2', 'classifier:liblinear_svc:tol': 0.005770138346204833, 'preprocessor:polynomial:degree': 2, 'preprocessor:polynomial:include_bias': 'True', 'preprocessor:polynomial:interaction_only': 'True', 'rescaling:quantile_transformer:n_quantiles': 683, 'rescaling:quantile_transformer:output_distribution': 'normal'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 635daed483007aa9eb9d0f13ef1e2ecb
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 573
#   Number of successful target algorithm runs: 552
#   Number of crashed target algorithm runs: 9
#   Number of target algorithms that exceeded the time limit: 1
#   Number of target algorithms that exceeded the memory limit: 11
#
# [WARNING] [2020-10-07 02:40:05,263:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 02:40:05,273:EnsembleBuilder(1):635daed483007aa9eb9d0f13ef1e2ecb] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 1.0 , test fscore:  0.9811320754716981
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'polynomial', 'rescaling:__choice__': 'quantile_transformer', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.7637054109802005, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 1, 'classifier:random_forest:min_samples_split': 7, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:polynomial:degree': 3, 'preprocessor:polynomial:include_bias': 'True', 'preprocessor:polynomial:interaction_only': 'True', 'rescaling:quantile_transformer:n_quantiles': 1178, 'rescaling:quantile_transformer:output_distribution': 'uniform'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 635daed483007aa9eb9d0f13ef1e2ecb
#   Metric: f1
#   Best validation score: 1.000000
#   Number of target algorithm runs: 127
#   Number of successful target algorithm runs: 124
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 3
#   Number of target algorithms that exceeded the memory limit: 0
#
#
#
# data_4 training data size: 9890 test data size: 2473
# [WARNING] [2020-10-07 03:40:17,997:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 03:40:18,007:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.9957710741471666 , test fscore:  0.9876819708846584
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'gradient_boosting', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'none', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:gradient_boosting:early_stop': 'train', 'classifier:gradient_boosting:l2_regularization': 0.0008726698604718266, 'classifier:gradient_boosting:learning_rate': 0.6635279662395932, 'classifier:gradient_boosting:loss': 'auto', 'classifier:gradient_boosting:max_bins': 256, 'classifier:gradient_boosting:max_depth': 'None', 'classifier:gradient_boosting:max_iter': 458, 'classifier:gradient_boosting:max_leaf_nodes': 51, 'classifier:gradient_boosting:min_samples_leaf': 46, 'classifier:gradient_boosting:scoring': 'loss', 'classifier:gradient_boosting:tol': 1e-07, 'preprocessor:select_rates:alpha': 0.1736392428668378, 'preprocessor:select_rates:mode': 'fdr', 'preprocessor:select_rates:score_func': 'f_classif', 'classifier:gradient_boosting:n_iter_no_change': 18},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 96e15f368892904cfcdb2aa7c67c362e
#   Metric: f1
#   Best validation score: 0.989831
#   Number of target algorithm runs: 199
#   Number of successful target algorithm runs: 186
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 6
#   Number of target algorithms that exceeded the memory limit: 7
#
# [WARNING] [2020-10-07 04:40:12,559:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 04:40:12,570:EnsembleBuilder(1):96e15f368892904cfcdb2aa7c67c362e] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.9892776523702032 , test fscore:  0.9841628959276018
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'liblinear_svc_preprocessor', 'rescaling:__choice__': 'minmax', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.3264473839036913, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 6, 'classifier:random_forest:min_samples_split': 18, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:liblinear_svc_preprocessor:C': 25.40668712707804, 'preprocessor:liblinear_svc_preprocessor:dual': 'False', 'preprocessor:liblinear_svc_preprocessor:fit_intercept': 'True', 'preprocessor:liblinear_svc_preprocessor:intercept_scaling': 1, 'preprocessor:liblinear_svc_preprocessor:loss': 'squared_hinge', 'preprocessor:liblinear_svc_preprocessor:multi_class': 'ovr', 'preprocessor:liblinear_svc_preprocessor:penalty': 'l1', 'preprocessor:liblinear_svc_preprocessor:tol': 0.0004333903223863082},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 96e15f368892904cfcdb2aa7c67c362e
#   Metric: f1
#   Best validation score: 0.992072
#   Number of target algorithm runs: 171
#   Number of successful target algorithm runs: 164
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 2
#   Number of target algorithms that exceeded the memory limit: 4
#
#
#
# data_5 training data size: 22965 test data size: 5742
# [WARNING] [2020-10-07 05:40:08,064:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 05:40:08,075:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 05:40:10,084:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 05:40:12,089:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.9877034781590349 , test fscore:  0.9526462395543175
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'gradient_boosting', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'minmax', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:gradient_boosting:early_stop': 'train', 'classifier:gradient_boosting:l2_regularization': 6.636109424752532e-10, 'classifier:gradient_boosting:learning_rate': 0.01998342676487636, 'classifier:gradient_boosting:loss': 'auto', 'classifier:gradient_boosting:max_bins': 256, 'classifier:gradient_boosting:max_depth': 'None', 'classifier:gradient_boosting:max_iter': 378, 'classifier:gradient_boosting:max_leaf_nodes': 983, 'classifier:gradient_boosting:min_samples_leaf': 20, 'classifier:gradient_boosting:scoring': 'loss', 'classifier:gradient_boosting:tol': 1e-07, 'preprocessor:select_rates:alpha': 0.4599227956932842, 'preprocessor:select_rates:mode': 'fwe', 'preprocessor:select_rates:score_func': 'chi2', 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.00029876262031783925, 'classifier:gradient_boosting:n_iter_no_change': 10},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 007e1b70e0021aaf0b98693d46275332
#   Metric: f1
#   Best validation score: 0.955378
#   Number of target algorithm runs: 162
#   Number of successful target algorithm runs: 142
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 5
#   Number of target algorithms that exceeded the memory limit: 15
#
# [WARNING] [2020-10-07 06:40:03,559:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 06:40:03,570:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 06:40:05,574:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 06:40:07,578:EnsembleBuilder(1):007e1b70e0021aaf0b98693d46275332] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.9844171060339778 , test fscore:  0.9494199535962878
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'select_rates', 'rescaling:__choice__': 'quantile_transformer', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.6144884352690955, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 2, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_rates:alpha': 0.4653150622495937, 'preprocessor:select_rates:mode': 'fdr', 'preprocessor:select_rates:score_func': 'f_classif', 'rescaling:quantile_transformer:n_quantiles': 1311, 'rescaling:quantile_transformer:output_distribution': 'uniform'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 007e1b70e0021aaf0b98693d46275332
#   Metric: f1
#   Best validation score: 0.949552
#   Number of target algorithm runs: 102
#   Number of successful target algorithm runs: 91
#   Number of crashed target algorithm runs: 0
#   Number of target algorithms that exceeded the time limit: 5
#   Number of target algorithms that exceeded the memory limit: 6
#
#
#
# data_6 training data size: 9167 test data size: 2293
# [WARNING] [2020-10-07 07:39:58,887:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 07:39:58,897:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 07:40:00,901:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 07:55:58,893:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 07:55:58,893:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# all-equipped, training fscore: 0.8381418092909535 , test fscore:  0.6572008113590264
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'minmax', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.6862425329078148, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 3, 'classifier:random_forest:min_samples_split': 13, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 4ab864c8876c543722442b506ccbf935
#   Metric: f1
#   Best validation score: 0.621782
#   Number of target algorithm runs: 180
#   Number of successful target algorithm runs: 158
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 3
#   Number of target algorithms that exceeded the memory limit: 18
#
# [WARNING] [2020-10-07 08:39:54,192:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 08:39:54,203:EnsembleBuilder(1):4ab864c8876c543722442b506ccbf935] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 09:25:33,658:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 09:25:33,658:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 09:33:35,194:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 09:33:35,194:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 09:39:45,637:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 09:39:45,637:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# random-forest-selected, training fscore: 0.8480318883906327 , test fscore:  0.6584362139917695
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'polynomial', 'rescaling:__choice__': 'standardize', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.5810004097699485, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 8, 'classifier:random_forest:min_samples_split': 2, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:polynomial:degree': 2, 'preprocessor:polynomial:include_bias': 'False', 'preprocessor:polynomial:interaction_only': 'False'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: 4ab864c8876c543722442b506ccbf935
#   Metric: f1
#   Best validation score: 0.620123
#   Number of target algorithm runs: 182
#   Number of successful target algorithm runs: 164
#   Number of crashed target algorithm runs: 6
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 8
# data_7 training data size: 8193 test data size: 2049
# [WARNING] [2020-10-07 09:39:50,759:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 09:39:50,769:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 09:39:52,773:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# all-equipped, training fscore: 0.9368635437881874 , test fscore:  0.7921348314606742
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'gradient_boosting', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'none', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'False', 'classifier:gradient_boosting:early_stop': 'train', 'classifier:gradient_boosting:l2_regularization': 8.60022601377178e-09, 'classifier:gradient_boosting:learning_rate': 0.02197330995118594, 'classifier:gradient_boosting:loss': 'auto', 'classifier:gradient_boosting:max_bins': 256, 'classifier:gradient_boosting:max_depth': 'None', 'classifier:gradient_boosting:max_iter': 477, 'classifier:gradient_boosting:max_leaf_nodes': 13, 'classifier:gradient_boosting:min_samples_leaf': 2, 'classifier:gradient_boosting:scoring': 'loss', 'classifier:gradient_boosting:tol': 1e-07, 'classifier:gradient_boosting:n_iter_no_change': 4},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: a619ef2c1fe74f7db94dc7cc716bf72b
#   Metric: f1
#   Best validation score: 0.841808
#   Number of target algorithm runs: 168
#   Number of successful target algorithm runs: 150
#   Number of crashed target algorithm runs: 3
#   Number of target algorithms that exceeded the time limit: 5
#   Number of target algorithms that exceeded the memory limit: 10
#
# [WARNING] [2020-10-07 10:39:45,956:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 10:39:45,966:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 10:39:47,970:EnsembleBuilder(1):a619ef2c1fe74f7db94dc7cc716bf72b] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 11:03:43,588:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 11:03:43,588:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# random-forest-selected, training fscore: 0.8728571428571429 , test fscore:  0.7930029154518949
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'select_percentile_classification', 'rescaling:__choice__': 'none', 'classifier:random_forest:bootstrap': 'True', 'classifier:random_forest:criterion': 'gini', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.8576468646394523, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 4, 'classifier:random_forest:min_samples_split': 3, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100, 'preprocessor:select_percentile_classification:percentile': 76.16016335028455, 'preprocessor:select_percentile_classification:score_func': 'mutual_info'},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: a619ef2c1fe74f7db94dc7cc716bf72b
#   Metric: f1
#   Best validation score: 0.800000
#   Number of target algorithm runs: 234
#   Number of successful target algorithm runs: 217
#   Number of crashed target algorithm runs: 5
#   Number of target algorithms that exceeded the time limit: 3
#   Number of target algorithms that exceeded the memory limit: 9
#
#
#
# data_8 training data size: 7659 test data size: 1916
# [WARNING] [2020-10-07 11:39:40,945:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 11:39:40,955:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 11:39:42,959:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 12:09:54,876:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2020-10-07 12:09:54,876:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# all-equipped, training fscore: 0.9180537772087068 , test fscore:  0.5696594427244581
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'gradient_boosting', 'imputation:strategy': 'most_frequent', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'minmax', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:gradient_boosting:early_stop': 'off', 'classifier:gradient_boosting:l2_regularization': 0.0021555710323131316, 'classifier:gradient_boosting:learning_rate': 0.14661680304442, 'classifier:gradient_boosting:loss': 'auto', 'classifier:gradient_boosting:max_bins': 256, 'classifier:gradient_boosting:max_depth': 'None', 'classifier:gradient_boosting:max_iter': 486, 'classifier:gradient_boosting:max_leaf_nodes': 111, 'classifier:gradient_boosting:min_samples_leaf': 50, 'classifier:gradient_boosting:scoring': 'loss', 'classifier:gradient_boosting:tol': 1e-07, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.0018198906478530867},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: fcf3cd40185117d08e556947af92a53e
#   Metric: f1
#   Best validation score: 0.612121
#   Number of target algorithm runs: 145
#   Number of successful target algorithm runs: 132
#   Number of crashed target algorithm runs: 1
#   Number of target algorithms that exceeded the time limit: 4
#   Number of target algorithms that exceeded the memory limit: 8
#
# [WARNING] [2020-10-07 12:39:36,332:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 12:39:36,341:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# [WARNING] [2020-10-07 12:39:38,345:EnsembleBuilder(1):fcf3cd40185117d08e556947af92a53e] No models better than random - using Dummy Score!
# random-forest-selected, training fscore: 0.8793407886992347 , test fscore:  0.5824742268041236
# [(1.000000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'random_forest', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'none', 'classifier:random_forest:bootstrap': 'False', 'classifier:random_forest:criterion': 'entropy', 'classifier:random_forest:max_depth': 'None', 'classifier:random_forest:max_features': 0.8525549885261304, 'classifier:random_forest:max_leaf_nodes': 'None', 'classifier:random_forest:min_impurity_decrease': 0.0, 'classifier:random_forest:min_samples_leaf': 5, 'classifier:random_forest:min_samples_split': 5, 'classifier:random_forest:min_weight_fraction_leaf': 0.0, 'classifier:random_forest:n_estimators': 100},
# dataset_properties={
#   'task': 1,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': False,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# auto-sklearn results:
#   Dataset name: fcf3cd40185117d08e556947af92a53e
#   Metric: f1
#   Best validation score: 0.623810
#   Number of target algorithm runs: 210
#   Number of successful target algorithm runs: 197
#   Number of crashed target algorithm runs: 2
#   Number of target algorithms that exceeded the time limit: 2
#   Number of target algorithms that exceeded the memory limit: 9
